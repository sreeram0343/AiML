# %% [markdown]
# Langchain Version V1

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# Creating an Agent

# %%
from langchain.agents import create_agent



agent=create_agent(
    model="gpt-5",
    tools=[],
    system_prompt="You are a helpful assistant"
)
agent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from langchain.agents import create_agent
#       2
#       3
#       4
#
# ImportError: cannot import name 'create_agent' from 'langchain.agents' (c:\Users\Thinkpad\Desktop\aiml\langchain\.venv\Lib\site-packages\langchain\agents\__init__.py)
